# %%
from pydantic import HttpUrl

url = HttpUrl("https://www.thehindu.com/opinion/editorial/the-second-issue-on-surrogacy-for-a-second-child/article70247684.ece")
print(url)
# Out:
# https://www.thehindu.com/opinion/editorial/the-second-issue-on-surrogacy-for-a-second-child/article70247684.ece

# %%
import asyncio
import pymongo
from pymongo import AsyncMongoClient
from dotenv import load_dotenv
import os

load_dotenv()



class DunduDb():
    def __init__(self):
        self.connection_string_atlas = os.getenv("DATABASE_URL")
        self.client = AsyncMongoClient(self.connection_string_atlas,server_api=pymongo.server_api.ServerApi(
            version="1"
        ))
        

    def insert_to_db(file):
        try:

# %%
connection_test=DunduDb()
